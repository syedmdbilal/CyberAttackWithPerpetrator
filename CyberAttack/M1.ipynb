# %% [markdown]
# # Module - 1

# %% [raw]
# Data Pre-Processing

# %%
import pandas as p
import numpy as n

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
data=p.read_csv('data.csv')

# %%
data.head()
# Out:
#    S.No                                  Crime  Gender                Age  \
# 0     0  Misuse of Debit Cards or Credit Cards    Male  Between 38 and 50
# 1     1  Misuse of Debit Cards or Credit Cards  Female       27 and Under
# 2     2  Misuse of Debit Cards or Credit Cards    Male  Between 38 and 50
# 3     3  Misuse of Debit Cards or Credit Cards    Male  Between 38 and 50
# 4     4  Misuse of Debit Cards or Credit Cards    Male  Between 38 and 50
#
#    Income        Job Maritalstatus          Education  \
# 0  Middle  Technical       Married  Primary Education
# 1     Low    Student        Single        High School
# 2     Low    Retired       Married  Primary Education
# 3     Low  Technical       Married        High School
# 4     Low     Others       Married        High School
#
#                                                 Harm  \
# 0                                              Fraud
# 1                 Internet Shopping Out of Knowledge
# ...

# %%
data.shape
# Out:
# (1802, 12)

# %%
data.size
# Out:
# 21624

# %%
data.isnull()
# Out:
#        S.No  Crime  Gender    Age  Income    Job  Maritalstatus  Education  \
# 0     False  False   False  False   False  False          False      False
# 1     False  False   False  False   False  False          False      False
# 2     False  False   False  False   False  False          False      False
# 3     False  False   False  False   False  False          False      False
# 4     False  False   False  False   False  False          False      False
# ...     ...    ...     ...    ...     ...    ...            ...        ...
# 1797  False  False   False  False   False  False          False      False
# 1798  False  False   False  False   False  False          False      False
# 1799  False  False   False  False   False  False          False      False
# 1800  False  False   False  False   False  False          False      False
# 1801  False  False   False  False   False  False          False      False
#
#        Harm  Attack  AttackMethod  Perpetrator
# ...

# %%
data.isnull().sum()
# Out:
# S.No             0
# Crime            0
# Gender           0
# Age              0
# Income           0
# Job              0
# Maritalstatus    0
# Education        0
# Harm             0
# Attack           0
# AttackMethod     0
# Perpetrator      0
# dtype: int64

# %%
data.columns
# Out:
# Index(['S.No', 'Crime', 'Gender', 'Age', 'Income', 'Job', 'Maritalstatus',
#        'Education', 'Harm', 'Attack', 'AttackMethod', 'Perpetrator'],
#       dtype='object')

# %%
data['Crime'].unique()
# Out:
# array(['Misuse of Debit Cards or Credit Cards',
#        'Hacking into the Information System and Capturing Data',
#        'Through Informatics Theft'], dtype=object)

# %%
data['Age'].unique()
# Out:
# array(['Between 38 and 50', '27 and Under', '51 and Above',
#        'Between 28 and 37'], dtype=object)

# %%
data['Job'].unique()
# Out:
# array(['Technical', 'Student', 'Retired', 'Others',
#        'Justice and Security', 'IT Sector', 'Housewife',
#        'Health Sector Manager', 'Education', 'Finance Sector'],
#       dtype=object)

# %%
data['Harm'].unique()
# Out:
# array(['Fraud', 'Internet Shopping Out of Knowledge',
#        'Internet Shopping by Intoducing Himself as a Bank Clerk',
#        'Withdrawing Money by Introducing Himself as a Bank Clerk',
#        'Withdrawals Without Knowledge', 'Do Moral Harm',
#        'Threating / Blackmailing'], dtype=object)

# %%
data['Attack'].unique()
# Out:
# array(['Hacking Social Media Accounts',
#        'Obtaining Electronic Bank Accounts',
#        'Obtaining and Using Data in Digital Environment',
#        'Copying Bank / ATM Cards', 'Selling Counterfeit Products'],
#       dtype=object)

# %%
data['AttackMethod'].unique()
# Out:
# array(['Creating a Fake Shopping Site', 'Social Engineering',
#        'Hacking Tools or Malware', 'Card Copying / Generating Devices',
#        'Receiving Public Data on Social Media', 'Phishing Attack'],
#       dtype=object)

# %%
data[data["Harm"] == 'Fraud']
# Out:
#       S.No                                  Crime  Gender                Age  \
# 0        0  Misuse of Debit Cards or Credit Cards    Male  Between 38 and 50
# 24      24  Misuse of Debit Cards or Credit Cards    Male       51 and Above
# 51      51  Misuse of Debit Cards or Credit Cards    Male  Between 38 and 50
# 57      57  Misuse of Debit Cards or Credit Cards    Male       51 and Above
# 60      60  Misuse of Debit Cards or Credit Cards    Male  Between 38 and 50
# ...    ...                                    ...     ...                ...
# 1291  1291  Misuse of Debit Cards or Credit Cards  Female  Between 38 and 50
# 1292  1292  Misuse of Debit Cards or Credit Cards    Male  Between 38 and 50
# 1299  1299  Misuse of Debit Cards or Credit Cards  Female  Between 28 and 37
# 1304  1304  Misuse of Debit Cards or Credit Cards    Male       27 and Under
# 1427  1427  Misuse of Debit Cards or Credit Cards  Female  Between 38 and 50
#
# ...

# %%
data[data["Income"] == 'High' ].head()
# Out:
#     S.No                                  Crime  Gender                Age  \
# 6      6  Misuse of Debit Cards or Credit Cards    Male       51 and Above
# 53    53  Misuse of Debit Cards or Credit Cards    Male  Between 38 and 50
# 61    61  Misuse of Debit Cards or Credit Cards  Female       51 and Above
# 65    65  Misuse of Debit Cards or Credit Cards    Male       27 and Under
# 72    72  Misuse of Debit Cards or Credit Cards    Male  Between 28 and 37
#
#    Income                   Job Maritalstatus       Education  \
# 6    High  Justice and Security       Married  Under Graduate
# 53   High  Justice and Security       Married  Under Graduate
# 61   High  Justice and Security       Married  Under Graduate
# 65   High  Justice and Security        Single  Under Graduate
# 72   High  Justice and Security       Married  Under Graduate
#
#                                   Harm                         Attack  \
# ...

# %%
data[data["Income"] == 'Low' ]
# Out:
#       S.No                                  Crime  Gender                Age  \
# 1        1  Misuse of Debit Cards or Credit Cards  Female       27 and Under
# 2        2  Misuse of Debit Cards or Credit Cards    Male  Between 38 and 50
# 3        3  Misuse of Debit Cards or Credit Cards    Male  Between 38 and 50
# 4        4  Misuse of Debit Cards or Credit Cards    Male  Between 38 and 50
# 5        5  Misuse of Debit Cards or Credit Cards    Male       51 and Above
# ...    ...                                    ...     ...                ...
# 1795  1795              Through Informatics Theft  Female  Between 28 and 37
# 1796  1796              Through Informatics Theft  Female  Between 28 and 37
# 1798  1798              Through Informatics Theft    Male       51 and Above
# 1799  1799              Through Informatics Theft  Female       27 and Under
# 1800  1800              Through Informatics Theft  Female  Between 38 and 50
#
# ...

# %%
data[data["Gender"] == 'Male'].shape
# Out:
# (1312, 12)

# %%
data[data["Gender"] == 'Female'].shape
# Out:
# (490, 12)

# %%
data.tail()
# Out:
#       S.No                      Crime  Gender                Age  Income  \
# 1797  1797  Through Informatics Theft    Male       51 and Above  Middle
# 1798  1798  Through Informatics Theft    Male       51 and Above     Low
# 1799  1799  Through Informatics Theft  Female       27 and Under     Low
# 1800  1800  Through Informatics Theft  Female  Between 38 and 50     Low
# 1801  1801  Through Informatics Theft  Female       27 and Under  Middle
#
#             Job Maritalstatus          Education  \
# 1797  Education       Married        High School
# 1798    Retired       Married        High School
# 1799  Technical        Single  Primary Education
# 1800  Housewife       Married        High School
# 1801  Technical        Single        High School
#
#                                Harm  \
# 1797                  Do Moral Harm
# 1798  Withdrawals Without Knowledge
# 1799  Withdrawals Without Knowledge
# 1800  Withdrawals Without Knowledge
# 1801  Withdrawals Without Knowledge
#
# ...

# %%
data.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1797    False
# 1798    False
# 1799    False
# 1800    False
# 1801    False
# Length: 1802, dtype: bool

# %%
data.duplicated().sum()
# Out:
# 0

# %%
df = data.dropna()

# %%
sum(df.isnull().sum())
# Out:
# 0

# %%
df.shape
# Out:
# (1802, 12)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1802 entries, 0 to 1801
# Data columns (total 12 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   S.No           1802 non-null   int64
#  1   Crime          1802 non-null   object
#  2   Gender         1802 non-null   object
#  3   Age            1802 non-null   object
#  4   Income         1802 non-null   object
#  5   Job            1802 non-null   object
#  6   Maritalstatus  1802 non-null   object
#  7   Education      1802 non-null   object
#  8   Harm           1802 non-null   object
#  9   Attack         1802 non-null   object
#  10  AttackMethod   1802 non-null   object
#  11  Perpetrator    1802 non-null   object
# dtypes: int64(1), object(11)
# memory usage: 183.0+ KB

# %%
df.columns
# Out:
# Index(['S.No', 'Crime', 'Gender', 'Age', 'Income', 'Job', 'Maritalstatus',
#        'Education', 'Harm', 'Attack', 'AttackMethod', 'Perpetrator'],
#       dtype='object')

# %%
p.crosstab(df["Attack"], df["AttackMethod"])
# Out:
# AttackMethod                                     Card Copying / Generating Devices  \
# Attack
# Copying Bank / ATM Cards                                                         0
# Hacking Social Media Accounts                                                  120
# Obtaining Electronic Bank Accounts                                               0
# Obtaining and Using Data in Digital Environment                                 14
# Selling Counterfeit Products                                                     0
#
# AttackMethod                                     Creating a Fake Shopping Site  \
# Attack
# Copying Bank / ATM Cards                                                     0
# Hacking Social Media Accounts                                              222
# Obtaining Electronic Bank Accounts                                           0
# Obtaining and Using Data in Digital Environment                             58
# ...

# %%
p.crosstab(df["Crime"], df["Perpetrator"])
# Out:
# Perpetrator                                         Known  UnKnown
# Crime
# Hacking into the Information System and Capturi...    130       50
# Misuse of Debit Cards or Credit Cards                 530      528
# Through Informatics Theft                             122      442

# %%
p.crosstab(df.Attack,df.Perpetrator)
# Out:
# Perpetrator                                      Known  UnKnown
# Attack
# Copying Bank / ATM Cards                            94      130
# Hacking Social Media Accounts                      492      458
# Obtaining Electronic Bank Accounts                  38       70
# Obtaining and Using Data in Digital Environment     80      348
# Selling Counterfeit Products                        78       14

# %%
df["Crime"].value_counts()
# Out:
# Misuse of Debit Cards or Credit Cards                     1058
# Through Informatics Theft                                  564
# Hacking into the Information System and Capturing Data     180
# Name: Crime, dtype: int64

# %%
df["AttackMethod"].value_counts()
# Out:
# Social Engineering                       964
# Creating a Fake Shopping Site            280
# Receiving Public Data on Social Media    224
# Card Copying / Generating Devices        134
# Hacking Tools or Malware                 108
# Phishing Attack                           92
# Name: AttackMethod, dtype: int64

# %%
p.Categorical(df["Attack"]).describe()
# Out:
#                                                  counts     freqs
# categories
# Copying Bank / ATM Cards                            224  0.124306
# Hacking Social Media Accounts                       950  0.527192
# Obtaining Electronic Bank Accounts                  108  0.059933
# Obtaining and Using Data in Digital Environment     428  0.237514
# Selling Counterfeit Products                         92  0.051054

# %%
from sklearn.preprocessing import LabelEncoder
l = LabelEncoder()
columns = ['S.No', 'Crime', 'Gender', 'Age', 'Income', 'Job', 'Maritalstatus',
       'Education', 'Harm', 'Attack', 'AttackMethod', 'Perpetrator']
for column in columns:
    df[column] = l.fit_transform(df[column]).astype(int)

# %%
df
# Out:
#       S.No  Crime  Gender  Age  Income  Job  Maritalstatus  Education  Harm  \
# 0        0      1       1    3       2    9              0          2     1
# 1        1      1       0    0       1    8              1          1     2
# 2        2      1       1    3       1    7              0          2     2
# 3        3      1       1    3       1    9              0          1     3
# 4        4      1       1    3       1    6              0          1     2
# ...    ...    ...     ...  ...     ...  ...            ...        ...   ...
# 1797  1797      2       1    1       2    0              0          1     0
# 1798  1798      2       1    1       1    7              0          1     5
# 1799  1799      2       0    0       1    9              1          2     5
# 1800  1800      2       0    3       1    3              0          1     5
# 1801  1801      2       0    0       2    9              1          1     5
#
#       Attack  AttackMethod  Perpetrator
# ...

# %%
df.corr()
# Out:
#                    S.No     Crime    Gender       Age    Income       Job  \
# S.No           1.000000  0.268073 -0.107670 -0.073293 -0.034236 -0.029119
# Crime          0.268073  1.000000 -0.237805 -0.008191 -0.063181 -0.102847
# Gender        -0.107670 -0.237805  1.000000  0.142829  0.032175  0.176279
# Age           -0.073293 -0.008191  0.142829  1.000000  0.110287 -0.108884
# Income        -0.034236 -0.063181  0.032175  0.110287  1.000000 -0.092378
# Job           -0.029119 -0.102847  0.176279 -0.108884 -0.092378  1.000000
# Maritalstatus  0.088998  0.050194 -0.284636 -0.450486 -0.108141  0.086361
# Education     -0.050873 -0.040659  0.057562  0.042025 -0.162012  0.239153
# Harm           0.070474 -0.231643  0.080345  0.052463  0.001779 -0.029589
# Attack         0.177265  0.051459  0.013549 -0.014358 -0.049182 -0.024657
# AttackMethod   0.056369  0.330578 -0.049627  0.082491 -0.005811  0.004522
# Perpetrator    0.073261  0.322579 -0.082140  0.065558 -0.046901 -0.117698
#
# ...

# %%
df.describe()
# Out:
#              S.No        Crime       Gender          Age       Income  \
# count  1802.00000  1802.000000  1802.000000  1802.000000  1802.000000
# mean    900.50000     1.213097     0.728080     1.641509     1.347392
# std     520.33691     0.606357     0.445072     1.155922     0.628993
# min       0.00000     0.000000     0.000000     0.000000     0.000000
# 25%     450.25000     1.000000     0.000000     1.000000     1.000000
# 50%     900.50000     1.000000     1.000000     2.000000     1.000000
# 75%    1350.75000     2.000000     1.000000     3.000000     2.000000
# max    1801.00000     2.000000     1.000000     3.000000     2.000000
#
#                Job  Maritalstatus    Education         Harm       Attack  \
# count  1802.000000    1802.000000  1802.000000  1802.000000  1802.000000
# mean      6.561598       0.304107     0.976693     2.776915     1.563818
# std       2.881681       0.460156     0.879472     1.811849     1.129868
# ...
